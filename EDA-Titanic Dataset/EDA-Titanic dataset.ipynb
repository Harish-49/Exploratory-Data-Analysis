# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Titanic Dataset
# ---

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
df=pd.read_csv("D:\HARISH\Gateway\Titanic.txt",sep=',')
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Data Cleaning

# %%
cols=df.columns
cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Droping unwanted columns

# %% [markdown]
# - 75 % of the datas in Parch is 0, Hence Parch can be droped.
# - 75 % of the datas in Cabin is NaN, Hence Cabin can be droped.

# %%
df=df.drop(['PassengerId','Name','Parch','Ticket', 'Cabin'],axis=1)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.shape
# Out:
# (712, 7)

# %%
df.duplicated().sum()
# Out:
# 38

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (674, 7)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp        Fare
# count  674.000000  674.000000  674.000000  674.000000  674.000000
# mean     0.416914    2.225519   29.752849    0.537092   35.720580
# std      0.493415    0.846039   14.693174    0.947016   54.101153
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000   16.100000
# 75%      1.000000    3.000000   39.000000    1.000000   34.584400
# max      1.000000    3.000000   80.000000    5.000000  512.329200

# %% [markdown]
# ### Kurtosis drop

# %%
df.kurt()
# Out:
# Survived    -1.891525
# Pclass      -1.459305
# Age          0.108240
# SibSp        6.619076
# Fare        29.561656
# dtype: float64

# %%
#References
sns.distplot(df.SibSp)

# %%
df.SibSp=np.sqrt(df.SibSp)
df.kurt()
# Out:
# Survived    -1.891525
# Pclass      -1.459305
# Age          0.108240
# SibSp       -0.032971
# Fare        29.561656
# dtype: float64

# %%
#References
sns.distplot(df.SibSp)

# %%
#References
sns.distplot(df.Fare)

# %%
df[df.Fare>100].index
# Out:
# Int64Index([ 27,  88, 118, 195, 215, 258, 268, 269, 297, 299, 305, 307, 311,
#             318, 319, 325, 332, 337, 341, 373, 377, 380, 390, 393, 435, 438,
#             498, 505, 537, 544, 550, 581, 609, 659, 660, 679, 689, 698, 700,
#             708, 716, 730, 737, 742, 763, 779, 802, 856],
#            dtype='int64')

# %%
df.drop([ 27,  88, 118, 195, 215, 258, 268, 269, 297, 299, 305, 307, 311,
            318, 319, 325, 332, 337, 341, 373, 377, 380, 390, 393, 435, 438,
            498, 505, 537, 544, 550, 581, 609, 659, 660, 679, 689, 698, 700,
            708, 716, 730, 737, 742, 763, 779, 802, 856],inplace=True)

# %%
df.kurt()
# Out:
# Survived   -1.806682
# Pclass     -1.161681
# Age         0.159290
# SibSp       0.133472
# Fare        1.673455
# dtype: float64

# %%
df.head(50)
# Out:
#     Survived  Pclass     Sex   Age     SibSp     Fare Embarked
# 0          0       3    male  22.0  1.000000   7.2500        S
# 1          1       1  female  38.0  1.000000  71.2833        C
# 2          1       3  female  26.0  0.000000   7.9250        S
# 3          1       1  female  35.0  1.000000  53.1000        S
# 4          0       3    male  35.0  0.000000   8.0500        S
# 6          0       1    male  54.0  0.000000  51.8625        S
# 7          0       3    male   2.0  1.732051  21.0750        S
# 8          1       3  female  27.0  0.000000  11.1333        S
# 9          1       2  female  14.0  1.000000  30.0708        C
# 10         1       3  female   4.0  1.000000  16.7000        S
# 11         1       1  female  58.0  0.000000  26.5500        S
# 12         0       3    male  20.0  0.000000   8.0500        S
# 13         0       3    male  39.0  1.000000  31.2750        S
# 14         0       3  female  14.0  0.000000   7.8542        S
# ...

# %%
df.shape
# Out:
# (626, 7)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp        Fare
# count  626.000000  626.000000  626.000000  626.000000  626.000000
# mean     0.391374    2.319489   29.583866    0.408095   23.966913
# std      0.488448    0.804092   14.701927    0.599660   21.352192
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.000000    0.000000   14.500000
# 75%      1.000000    3.000000   38.750000    1.000000   29.700000
# max      1.000000    3.000000   80.000000    2.236068   93.500000

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate

# %%
df.hist(bins=50,figsize=(25,15))
plt.show()

# %%
sns.countplot(df.Pclass)

# %% [markdown]
# - 3 rd class Passengers were alive compared to other class passengers.

# %%
sns.countplot(df.SibSp)

# %%
sns.countplot(df.Embarked)

# %% [markdown]
# - Most of the passengers are embarked to Southampton.

# %%
a=[df.Embarked.value_counts()]
b=['S','C','Q']
plt.pie(a,labels=b,autopct="%d")
plt.show()
# Out:
# <ipython-input-32-70ba2b5cbba0>:3: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(a,labels=b,autopct="%d")

# %% [markdown]
# - the passengers who were not survived are mostly Embarked to Southampton.

# %%
sns.countplot(df.Sex)

# %% [markdown]
# - the non survived passengers are mostly Male.

# %% [markdown]
# ## Bivariate

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'], dtype='object')

# %% [markdown]
# ### Numerical

# %% [markdown]
# - Comparing Passenger class with target feature.

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['Pclass'][df.Survived==0])
sns.distplot(df['Pclass'][df.Survived==1])
plt.show()

# %% [markdown]
# - Comparing Age with target feature.

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['Age'][df.Survived==0])
sns.distplot(df['Age'][df.Survived==1])
plt.show()

# %% [markdown]
# - Comparing Sibling with target feature.

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['SibSp'][df.Survived==0])
sns.distplot(df['SibSp'][df.Survived==1])
plt.show()

# %% [markdown]
# - Comparing Fare with target feature.

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['Fare'][df.Survived==0])
sns.distplot(df['Fare'][df.Survived==1])
plt.show()

# %% [markdown]
# ### Categorical

# %% [markdown]
# - Comparing Gender with target feature.

# %%
pivot = pd.crosstab(df.Sex,df.Survived,margins=True)
print(pivot)
print()
ratio = pivot[1]/pivot['All']
print(ratio)
ratio.plot(kind='bar')
# Out:
# Survived    0    1  All
# Sex
# female     62  160  222
# male      319   85  404
# All       381  245  626
#
# Sex
# female    0.720721
# male      0.210396
# All       0.391374
# dtype: float64

# %% [markdown]
# - Comparing Embarked with target feature.

# %%
pivot = pd.crosstab(df.Embarked,df.Survived,margins=True)
print(pivot)
print()
ratio = pivot[1]/pivot['All']
print(ratio)
ratio.plot(kind='bar')
# Out:
# Survived    0    1  All
# Embarked
# C          44   58  102
# Q          20    8   28
# S         317  179  496
# All       381  245  626
#
# Embarked
# C      0.568627
# Q      0.285714
# S      0.360887
# All    0.391374
# dtype: float64

# %% [markdown]
# ## Multivariate

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'], dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df.Pclass,y=df.Age,hue=df.Survived,data=df)

# %%
#plt.figure(figsize=(15,10))
sns.scatterplot(x=df.Pclass,y=df.SibSp,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df.Pclass,y=df.Fare,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df.Fare,y=df.Age,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df.SibSp,y=df.Age,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df.SibSp,y=df.Fare,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x=df.Sex,y=df.Age,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x=df.Pclass,y=df.Sex,hue=df.Survived,data=df)

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x=df.Sex,y=df.Fare,hue=df.Survived,data=df)

# %%
sns.catplot(y='Pclass',x='Embarked',hue='Survived',data=df,kind='bar')

# %%
sns.catplot(data=df, kind="bar",hue="Sex", x="Pclass", y="Age")

# %%
sns.catplot(data=df, kind="bar",x="Embarked", hue="Pclass", y="Survived")

# %% [markdown]
# ### The important features are ** Pclass, Age, Fare, SibSP.**

# %% [markdown]
# ## Statistical Analysis

# %%
cor=df.corr()
cor
# Out:
#           Survived    Pclass       Age     SibSp      Fare
# Survived  1.000000 -0.318873 -0.103838  0.018466  0.266844
# Pclass   -0.318873  1.000000 -0.392242  0.027030 -0.685688
# Age      -0.103838 -0.392242  1.000000 -0.257241  0.151627
# SibSp     0.018466  0.027030 -0.257241  1.000000  0.335714
# Fare      0.266844 -0.685688  0.151627  0.335714  1.000000

# %%
plt.figure(figsize=(20,12))
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# - From Correlation table the important features are **Pclass, Age, Fare.**

# %% [markdown]
# ## Anova

# %% [markdown]
# - Used to compare means of two or more samples, to check whether the means are similar or not
#  - For Example => Here the dataset denotes that the passengers of the Titanic are survived or not.
#  - NULL HYPOTHESIS => means of two or more groups are similar to each other
#  - Alternate Hypothesis => means of two or more grups are different than each other.
#
#  For a CI = 95%, alpha = 1 - CI = 1 - 0.95 = 0.05
#
#  - if pvalue > alpha = accept the Null Hypothesis, feature is not important
#  - if pvalue < alpha = reject the Null Hypothesis, feature is important

# %%
num=['Pclass', 'Age', 'SibSp', 'Fare']

# %%
x=df[num]
y=df['Survived']

# %%
from sklearn.feature_selection import f_classif

# %%
fval,pval = f_classif(x,y)

# %%
for i in range(len(num)):
    print(num[i],pval[i])
    print(pval[i]<0.05)
    print()
# Out:
# Pclass 2.918253351982081e-16
# True
#
# Age 0.009325909113877663
# True
#
# SibSp 0.6447084713394053
# False
#
# Fare 1.148550667649666e-11
# True

# %% [markdown]
# - From Anova test the important features are **Pclass, Age, Fare.**

# %% [markdown]
# ## Chi Square

# %% [markdown]
# - used to compare the distribution of a categorical feature in two or more groups
#
# - NULL HYPOTHESIS H0 = the distribution of categories in two or more groups is similar
# - Alternate Hypothesis, Ha = the distribution of categories in two or more groups is different
#
# for CI = 95%, alpha = 1 - CI = 1 - 0.95 = 0.05
#
# - if pvalue>alpha = accpet the Null Hypothesis, feature is not important
# - if pvalue < alpha = reject the Null Hypothesis, feautre is important.

# %%
cat=['Sex','Embarked']
x=df[cat]
y=df.Survived

# %%
from sklearn.preprocessing import LabelEncoder as le

# %%
x.Sex = le().fit_transform(x.Sex)
x.Embarked = le().fit_transform(x.Embarked)
# Out:
# C:\Users\haris\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
from sklearn.feature_selection import chi2

# %%
cval,pval = chi2(x,y)
for i in range(len(cat)):
    print(cat[i],pval[i])
    print(pval[i]<0.05)
    print()
# Out:
# Sex 9.108020078001755e-14
# True
#
# Embarked 0.033170028411553726
# True

# %% [markdown]
# - From chi2 test the important features are **Sex, Embarked.**

# %% [markdown]
# #### These are the important features derived from Statistical Analysis.

# %% [markdown]
# #### With the Statistical Analysis and Data visualization we can finalize the important features.

# %% [markdown]
# The Important features are,
# - Pclass
# - Age
# - Fare
# - Sex
# - Embarked
